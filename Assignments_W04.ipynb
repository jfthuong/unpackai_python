# %% [markdown]
# # ⇝ Assignments Week 04 ⇜
#
# ### To be finished before Monday 21st June
#
# ![unpackAI Logo](images/unpackAI_logo_whiteBG.svg)

# %% [markdown]
# # **(MUST)** 👀 Watch following lessons
#
# * [Lesson #14](https://store.lerner.co.il/courses/python-for-non-programmers-live/351353-lesson-14-modules-and-packages/1000373-lesson-14-2020-june-26-mp4): **Modules** (start at 2:20)
# * [Lesson #15](https://store.lerner.co.il/courses/python-for-non-programmers-live/360074-lesson-15-where-to-from-here/1025437-lesson-15-2020-july-3-mp4): **Where to from here** (start at 2:56)
#
# 🛎Do the Homework of course between each lesson (see next assignment for details)
#
# NOTE: No Homework for the last lesson :)

# %% [markdown]
# # (MUST) 👣 Perform Homework of each lesson
#
# ### 🤗For more convenience, we have copied the Homework from the Online Course directly in this Notebook.
#
# ### 💡You can download this Jupyter Notebook and do it directly! :)
#
# If you are seeing this Notebook from Github and want to download to your computer, you can do the following (you can also see the [tutorial](https://ior.ad/7Bvk)):
#
# 1. Click on **Raw** button (the URL of the page shall now start with _raw.githubusercontent.com_)
# 2. Save the page (**Ctrl** + **S**) and save in your computer with the extension **.ipynb** (e.g. _Assignments_W02.ipynb_)
# 3. Open the downloaded Jupyter Notebook with Visual Studio Code (or Jupyter if you prefer)
#
# Alternatively, you could have a look at the amazing project called [Gitpod](https://gitpod.io/) which allows you to code from Github directly or use Notebooks directly from your browser.

# %% [markdown]
# ## 👣Homework Lesson #14
#
# (_copied from [this page](https://store.lerner.co.il/courses/python-for-non-programmers-live/351353-lesson-14-modules-and-packages/1000346-lesson-14-2020-june-26-ipynb)_)
#
#
# Here are some homework problems for this lesson:
#
# 1. Write a function that gets a directory name, and returns a dict whose keys are the file extensions (i.e., the stuff at the end, like `.txt` or `.jpg`, but following the dot) and whose values are the number of files with such an extension. You’ll likely want to use `os.listdir` or `glob.glob`, which work a bit differently; the first is easier to use, if you’re not sure!  ... \[ADDED BY JEFF\] You can also use `Path().glob` in `pathlib`: see [here](https://docs.python.org/3/library/pathlib.html#pathlib.Path.glob)
#
# 2. The `random` module includes a function, `random.choice`, that can return a random element from any sequence (including a string). Write a function that takes a list, chooses a random element from it, and then asks the user to repeatedly guess which element has been chosen. When the user guesses correctly, the function returns the number of guesses it took.
#
# 3. \[OPTIONAL\] This is a bit harder, but worth trying a bit: The `pickle` module lets you turn data structures into bytestrings _\[JEFF: basically it is a file that cannot be understood by human, only by machines\]_, and back. That’s normally used for storing data on disk and then retrieving it later. You take a data structure and turn it into a bytestring with `pickle.dumps`, which returns a bytestring. You can then take a bytestring and turn it back into data with `pickle.loads`. Create a `dict` in which the keys are strings and the values are integers, strings, or lists (not too many). Use `pickle.dumps` to turn it into a bytestring. Then turn it back into a data structure… are they the same?
#
# NOTE: If you want to learn more about `pickle`, you can check this simple tutorial: https://www.tutorialspoint.com/python-pickling

# %%
# TODO: Write here the solution for Homework #14

# %% [markdown]
# # (MUST) 💻 Realize a Project
#
# This week, we will not have any coding challenge. Instead, you will do a "project", which consists in:
#
# 1. Selecting a project that looks interesting for you, and has not been chosen by any other team member (first come, first served)
# 2. Following the step-by-step tutorial that guide you towards the finalization of the project
# 3. Trying to customize the project (e.g. using different data / website, or deploying your project online)
# 4. Preparing the presentation to your peers in next Mentor session
#
# ---
#
# 💡_Reminder_: You will probably have to install the modules you need for your project with `pip install <module name>`.
# If you are using MacOS, you should do `python3 -m pip install ...` instead of `pip install ...`
#
# Here are the list of `<module name>` for the different modules:
#
# * BeautifulSoup: `pip install beautifulsoup4`
# * Flask: `pip install Flask`
# * pandas: `pip install pandas`
# * matplotlib: `pip install matplotlib`
# * csv: nothing to do (by default in Python)
# * yfinance: `pip install yfinance`
# * statsmodels: `pip install statsmodels`
# * scikit-learn: `pip install scikit-learn`
# * wordcloud: `pip install wordcloud` (but installed automatically in Repl.it)
# * feedparser: `pip install feedparser` (but installed automatically in Repl.it)
#
# You can also group installation in a single command, like this: `pip install Flask beautifulsoup4 pandas matplotlib`.

# %% [markdown]
# ### You can select your project via the following Doodle Link: https://doodle.com/poll/drb9hrptrak4amdg?utm_source=poll
#
# Here are the projects available.
#
# ---
#
#
# ###1. Web Scraping Python Tutorial – How to Scrape Data From A Website
#
# |            |                       |
# |------------|-----------------------|
# | Difficulty | Beginner              |
# | Concepts   | Web Scrapping         |
# | Modules    | BeautifulSoup, csv    |
# | Link       | https://www.freecodecamp.org/news/web-scraping-python-tutorial-how-to-scrape-data-from-a-website/ |
#
# This project explores the basics of webscrapping, gather data from a page (created for the tutorial).
# It stores the data into a csv file (by using the `csv` module).
#
# ---
#
# ###2. The Fundamentals of Web Scraping
#
# |            |                       |
# |------------|-----------------------|
# | Difficulty | Intermediate          |
# | Concepts   | Web Scrapping         |
# | Modules    | BeautifulSoup, pandas |
# | Link       | https://www.dataquest.io/blog/web-scraping-python-using-beautiful-soup/ |
#
#
# This project goes through the core concept of web scrapping to get weather data from a (real) weather website.
# It stores these data in a pandas Dataframe (most popular module for Data Science).
#
# ---
#
# ###3. Hands-On Guide To Using YFinance API In Python
#
# |            |                              |
# |------------|------------------------------|
# | Difficulty | Intermediate                 |
# | Concepts   | API Connection               |
# | Modules    | yfinance, pandas, matplotlib |
# | Link       | https://analyticsindiamag.com/hands-on-guide-to-using-yfinance-api-in-python/ |
#
# This project connects to Yahoo Finance by using a module providing and API.
# It collects financial data of Pfizer (stocks, etc.), and draws graphs to visualize the results.
#
# ---
#
# ###4. Build a Weather API Dashboard with Python and Flask
#
# |            |                              |
# |------------|------------------------------|
# | Difficulty | Beginner+                    |
# | Concepts   | API Connection, Website      |
# | Modules    | flask                        |
# | Link       | https://thecodex.me/blog/weather-dashboard-python-and-flask |
#
# This project uses API to connect to OpenWeather website.
# It then creates a webpage where anyone can enter a location and see the weather of this location.
#
# NOTE: This project requires the code to be written in a Python file (`.py`); it cannot be written in Jupyter.
#
# ---
#
# ###5. Introduction to Linear Regression in Python
#
# |            |                              |
# |------------|------------------------------|
# | Difficulty | Intermediate                 |
# | Concepts   | Regression                   |
# | Modules    | statsmodels, scikit-learn, pandas, matplotlib |
# | Link       | https://towardsdatascience.com/introduction-to-linear-regression-in-python-c12a072bedf0 |
#
# This project goes through the core idea behind Linear Regression (and Multiple Linear Regression) based on real data.
# We then draws some graphs of the linear regression model.
# Finally, we uses the regression to predict some value: this is a first entrance to the world of Machine Learning.
#
# ---
#
# ###6. Hands-on Python `pandas.DataFrame`
#
# |            |                              |
# |------------|------------------------------|
# | Difficulty | Beginner                     |
# | Concepts   | Pandas                       |
# | Modules    | pandas, matplotlib           |
# | Link       | https://medium.com/ub-women-data-scholars/hands-on-python-pandas-dataframe-c8955f257171 |
#
# This project gives a good introduction to the Dataframes of pandas by exploring the famous data about Titanic Passengers.
# At the end, we draw a small graph, but we could extend by drawing different things.
#
# ---
#
# ###7. How to Build a Speech Recognition tool with Python and Flask
#
# |            |                              |
# |------------|------------------------------|
# | Difficulty | Intermediate+                |
# | Concepts   | Speechrecognition, Website   |
# | Modules    | Speechrecognition, Flask     |
# | Link       | https://thecodex.me/blog/speech-recognition-with-python-and-flask |
#
# This project builds a small web page to allow a user to upload a sound file (`.wav`) with people talking (in English)
# and the page will display is said in this sound file.
#
# ⚠ **WARNING: the project is using the Google Speech Recognition so it might be tricky in China with VPN and all**
# The module `Speechrecognition` can uses some other Speech Recognition systems (Bing, IBM, ...)
# but it might need some exploration to understand how it works.
#
# NOTE: This project requires the code to be written in a Python file (`.py`); it cannot be written in Jupyter.
#
# ---
#
# ###8. Building news word clouds using Python and Repl.it
#
# |            |                              |
# |------------|------------------------------|
# | Difficulty | Intermediate                 |
# | Concepts   | Web Scrapping, Website Deployment, Word clouds |
# | Modules    | feedparser, BeautifulSoup, Flask, wordcloud |
# | Link       | https://ritza.co/showcase/repl.it/building-news-word-clouds-using-python-and-repl-it.html |
#
# This project grabs the headlines from BBC news (by using RSS feed) and build a "word cloud" with the keywords.
# The project is showing the result on a webpage that is deployed and visible publicly by anyone in the World.
#
# This could be customized by grabbing news from other website :)
#
#
# NOTE: This project requires the code to be written in a Python file (`.py`)
# in **Repl.it**, which is an awesome free online code editor with advanced capabilities
# (like being able to run code online and deploy it super easily).
#
# ---

# %% [markdown]
# # (MUST) 🗣 Explain your project during Mentoring Session
#
# In Monday Mentoring Session, explain in 𝟝 minutes to your classmates and mentors:
# * What is the purpose of the project
# * What are the different steps
# * Any customizations you have done (if any)
# * The final result
# * The problems you met
# * What you have learned
#
# You have 8 minutes each.

# %% [markdown]
# -----
#
# ## 🔔Remember
#
# We are learning together as a community 👥 so make sure to voice out your educated questions 💬.
#
# While most confusions 🤷 can be solved the quickest by simply Googling or using [StackOverflow](https://stackoverflow.com/questions/ask), do not hold back any questions 🙋 if you have spent a fair amount researching 🔎.
